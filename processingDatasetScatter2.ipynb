# %%
import pandas as pd
import numpy as np
import re

# %%
game_dataset = pd.read_csv('dataset/games.csv')
game_dataset = game_dataset.sample(n=4000, random_state=1)

# %%
game_dataset2 = game_dataset.drop(columns=['active_players', 'avg_total_playtime', 'avg_recent_playtime', 'median_recent_playtime', 
                           'developer', 'porting', 'publisher', 'engine', 'mode', 'perspective', 'theme', 'more_tags'], axis=1)


#remove if estimated_players = 0
#remove if 
game_dataset2
# Out:
#       game_id  estimated_players             release_date  \
# 2454     3795                0.0  1970.01.01, 2009.03.29.
# 2193     3476                0.0                      NaN
# 3945     5339           244000.0  2010.01.08, 2009.09.04.
# 438      1439          1300000.0               2016.04.28
# 2869     4263           359000.0               2011.11.01
# ...       ...                ...                      ...
# 881      2097                0.0  2015.11.17, 2015.11.17.
# 2651     4028          4800000.0  2017.09.28, 2017.09.28.
# 3295     4689                0.0              2013.11.05.
# 772      1938                0.0              2009.02.05.
# 2155     3426                0.0               1970.01.01
#
#                                          genre
# 2454                                 ['Music']
# 2193                               ['Shooter']
# 3945      ['Shooter', 'Simulator', 'Strategy']
# 438   ['Action', 'Free to Play', 'Simulation']
# ...
